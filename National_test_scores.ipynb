# %%
#import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
#Import All CSV Files
#math
math_09 = pd.read_csv("Resources/Education Data/2009 Math .csv")
math_09_df = pd.DataFrame(math_09)
math_11 = pd.read_csv("Resources/Education Data/2011 Math .csv")
math_11_df = pd.DataFrame(math_11)
math_13 = pd.read_csv("Resources/Education Data/2013 math.csv")
math_13_df = pd.DataFrame(math_13)
math_15 = pd.read_csv("Resources/Education Data/2015 Math .csv")
math_15_df = pd.DataFrame(math_15)
math_17 = pd.read_csv("Resources/Education Data/2017 Math .csv")
math_17_df = pd.DataFrame(math_17)
math_19 = pd.read_csv("Resources/Education Data/2019 Math.csv")
math_19_df = pd.DataFrame(math_19)

#reading
reading_09 = pd.read_csv("Resources/Education Data/2009 Reading .csv")
reading_09_df = pd.DataFrame(reading_09)
reading_11 = pd.read_csv("Resources/Education Data/2011 reading .csv")
reading_11_df = pd.DataFrame(reading_11)
reading_13 = pd.read_csv("Resources/Education Data/2013 reading.csv")
reading_13_df = pd.DataFrame(reading_13)
reading_15 = pd.read_csv("Resources/Education Data/2015 Math .csv")
reading_15_df = pd.DataFrame(reading_15)
reading_17 = pd.read_csv("Resources/Education Data/2017 Reading .csv")
reading_17_df = pd.DataFrame(reading_17)
reading_19 = pd.read_csv("Resources/Education Data/2019 Reading.csv")
reading_19_df = pd.DataFrame(reading_19)

# %%
# Preview dfs
math_09_df
# Out:
#             Jurisdiction   MN SigDiff SigSymbol  AB  AP
# 0          Massachusetts  252      13         ▲  92  57
# 1          New Hampshire  251      12         ▲  92  56
# 2              Minnesota  249      10         ▲  89  54
# 3                Vermont  248       9         ▲  89  51
# 4             New Jersey  247       7         ▲  88  49
# 5                 Kansas  245       6         ▲  89  46
# 6           North Dakota  245       6         ▲  91  45
# 7            Connecticut  245       6         ▲  86  46
# 8                  Maine  244       5         ▲  87  45
# 9                Montana  244       5         ▲  88  45
# 10              Maryland  244       5         ▲  85  44
# 11        North Carolina  244       5         ▲  87  43
# 12                  Ohio  244       5         ▲  85  45
# 13          Pennsylvania  244       4         ▲  84  46
# 14             Wisconsin  244       4         ▲  85  45
# 15              Colorado  243       4         ▲  84  45
# ...

# %%
#Drop SigDiff and SigSymbol off all csv
#math
math_09_df = math_09_df.drop(['SigDiff', 'SigSymbol', 'AB', 'AP'], axis=1)
math_11_df = math_11_df.drop(['SigDiff', 'SigSymbol', 'AB', 'AP'], axis=1)
math_13_df = math_13_df.drop(['SigDiff', 'SigSymbol', 'AB', 'AP'], axis=1)
math_15_df = math_15_df.drop(['SigDiff', 'SigSymbol', 'AB', 'AP'], axis=1)
math_17_df = math_17_df.drop(['SigDiff', 'SigSymbol', 'AB', 'AP'], axis=1)
math_19_df = math_19_df.drop(['SigDiff', 'SigSymbol', 'AB', 'AP'], axis=1)

#reading
reading_09_df = reading_09_df.drop(['SigDiff', 'SigSymbol', 'AB', 'AP'], axis=1)
reading_11_df = reading_11_df.drop(['SigDiff', 'SigSymbol', 'AB', 'AP'], axis=1)
reading_13_df = reading_13_df.drop(['SigDiff', 'SigSymbol', 'AB', 'AP'], axis=1)
reading_15_df = reading_15_df.drop(['SigDiff', 'SigSymbol', 'AB', 'AP'], axis=1)
reading_17_df = reading_17_df.drop(['SigDiff', 'SigSymbol', 'AB', 'AP'], axis=1)
reading_19_df = reading_19_df.drop(['SigDiff', 'SigSymbol', 'AB', 'AP'], axis=1)

# %%
#preview dfs
reading_09_df
# Out:
#             Jurisdiction   MN
# 0          Massachusetts  234
# 1             New Jersey  229
# 2          New Hampshire  229
# 3            Connecticut  229
# 4                Vermont  229
# 5                  DoDEA  228
# 6               Virginia  227
# 7               Maryland  226
# 8           North Dakota  226
# 9               Colorado  226
# 10               Florida  226
# 11              Kentucky  226
# 12              Delaware  226
# 13               Montana  225
# 14                  Ohio  225
# 15              New York  224
# 16                Kansas  224
# 17              Missouri  224
# 18                 Maine  224
# 19          Pennsylvania  224
# 20             Minnesota  223
# 21          Rhode Island  223
# 22               Indiana  223
# 23               Wyoming  223
# 24              Nebraska  223
# 25          South Dakota  222
# 26                  Iowa  221
# 27            Washington  221
# 28                 Idaho  221
# 29             Wisconsin  220
# ...

# %%
#rename column to include year, change Jurisdiction to State
#math
math_09_df = math_09_df.rename(columns = {'Jurisdiction' : 'State', 'MN' : 'NAEP Math Score 09'})
math_11_df = math_11_df.rename(columns = {'Jurisdiction' : 'State', 'MN' : 'NAEP Math Score 11'})
math_13_df = math_13_df.rename(columns = {'Jurisdiction' : 'State', 'MN' : 'NAEP Math Score 13'})
math_15_df = math_15_df.rename(columns = {'Jurisdiction' : 'State', 'MN' : 'NAEP Math Score 15'})
math_17_df = math_17_df.rename(columns = {'Jurisdiction' : 'State', 'MN' : 'NAEP Math Score 17'})
math_19_df = math_19_df.rename(columns = {'Jurisdiction' : 'State', 'MN' : 'NAEP Math Score 19'})

#reading
reading_09_df = reading_09_df.rename(columns = {'Jurisdiction' : 'State', 'MN' : 'NAEP Reading Score 09'})
reading_11_df = reading_11_df.rename(columns = {'Jurisdiction' : 'State', 'MN' : 'NAEP Reading Score 11'})
reading_13_df = reading_13_df.rename(columns = {'Jurisdiction' : 'State', 'MN' : 'NAEP Reading Score 13'})
reading_15_df = reading_15_df.rename(columns = {'Jurisdiction' : 'State', 'MN' : 'NAEP Reading Score 15'})
reading_17_df = reading_17_df.rename(columns = {'Jurisdiction' : 'State', 'MN' : 'NAEP Reading Score 17'})
reading_19_df = reading_19_df.rename(columns = {'Jurisdiction' : 'State', 'MN' : 'NAEP Reading Score 19'})

# %%
#preview dfs

reading_15_df
# Out:
#                    State  NAEP Reading Score 15
# 0          Massachusetts                    251
# 1              Minnesota                    250
# 2          New Hampshire                    249
# 3                Indiana                    248
# 4                  DoDEA                    248
# 5                Wyoming                    247
# 6               Virginia                    247
# 7             New Jersey                    245
# 8             Washington                    245
# 9           North Dakota                    245
# 10                 Texas                    244
# 11              Nebraska                    244
# 12        North Carolina                    244
# 13                  Ohio                    244
# 14                  Iowa                    243
# 15          Pennsylvania                    243
# 16             Wisconsin                    243
# 17               Vermont                    243
# 18               Florida                    243
# ...

# %%
#Merge the dfs
#math
new_math_df = math_09_df.merge(math_11_df, on = 'State')
new_math_df = new_math_df.merge(math_13_df, on = 'State')
new_math_df = new_math_df.merge(math_15_df, on = 'State')
new_math_df = new_math_df.merge(math_17_df, on = 'State')
new_math_df = new_math_df.merge(math_19_df, on = 'State')

#reading
new_reading_df = reading_09_df.merge(reading_11_df, on = 'State')
new_reading_df = new_reading_df.merge(reading_13_df, on = 'State')
new_reading_df = new_reading_df.merge(reading_15_df, on = 'State')
new_reading_df = new_reading_df.merge(reading_17_df, on = 'State')
new_reading_df = new_reading_df.merge(reading_19_df, on = 'State')

# %%
#preview dfs
new_math_df
# Out:
#                    State NAEP Math Score 09  NAEP Math Score 11  \
# 0          Massachusetts                252                 253
# 1          New Hampshire                251                 252
# 2              Minnesota                249                 249
# 3                Vermont                248                 247
# 4             New Jersey                247                 248
# 5                 Kansas                245                 246
# 6           North Dakota                245                 245
# 7            Connecticut                245                 242
# 8                  Maine                244                 244
# 9                Montana                244                 244
# 10              Maryland                244                 247
# 11        North Carolina                244                 245
# 12                  Ohio                244                 244
# 13          Pennsylvania                244                 246
# ...

# %%
#reset state as index
reset_math_df = new_math_df.set_index('State')
reset_reading_df = new_reading_df.set_index('State')

#drop DoDEA and Puerto Rico
clean_math_df = reset_math_df.drop(['DoDEA', 'Puerto Rico'])
clean_reading_df = reset_reading_df.drop(['DoDEA', 'Puerto Rico'])

# %%
#preview dfs
clean_math_df
# Out:
#                      NAEP Math Score 09  NAEP Math Score 11  \
# State
# Massachusetts                       252                 253
# New Hampshire                       251                 252
# Minnesota                           249                 249
# Vermont                             248                 247
# New Jersey                          247                 248
# Kansas                              245                 246
# North Dakota                        245                 245
# Connecticut                         245                 242
# Maine                               244                 244
# Montana                             244                 244
# Maryland                            244                 247
# North Carolina                      244                 245
# Ohio                                244                 244
# Pennsylvania                        244                 246
# ...

# %%
#calc average over time
clean_math_df['Average NAEP Math Score over 10 Years'] = clean_math_df.mean(axis = 1)
final_math_df = clean_math_df['Average NAEP Math Score over 10 Years']
final_math_df = final_math_df.round(2)
final_math_df = final_math_df.to_frame()
final_math_df = final_math_df.reindex(['National public', 'Massachusetts', 'New Hampshire', 'Minnesota', 'Vermont', 'New Jersey',
       'Kansas', 'North Dakota', 'Connecticut', 'Maine', 'Montana', 'Maryland',
       'North Carolina', 'Ohio', 'Pennsylvania', 'Wisconsin', 'Colorado',
       'Virginia', 'Indiana', 'Iowa', 'Washington', 'South Dakota', 'Wyoming',
       'Florida', 'Idaho', 'Missouri', 'New York', 'Texas', 'Utah', 'Delaware', 'Kentucky', 'Rhode Island', 'Nebraska', 'Illinois',
       'Oregon', 'Arkansas', 'Alaska', 'Oklahoma', 'Michigan', 'Georgia',
       'Hawaii', 'South Carolina', 'Nevada', 'West Virginia', 'Tennessee',
       'California', 'New Mexico', 'Arizona', 'Louisiana', 'Alabama',
       'Mississippi', 'District of Columbia'])

clean_reading_df['Average NAEP Reading Score over 10 Years'] = clean_reading_df.mean(axis = 1)
final_reading_df = clean_reading_df['Average NAEP Reading Score over 10 Years']
final_reading_df = final_reading_df.round(2)
final_reading_df = final_reading_df.to_frame()
final_reading_df = final_reading_df.reindex([ 'National public','Massachusetts', 'New Jersey', 'New Hampshire', 'Connecticut',
       'Vermont', 'Virginia', 'Maryland', 'North Dakota', 'Colorado',
       'Florida', 'Kentucky', 'Delaware', 'Montana', 'Ohio', 'New York',
       'Kansas', 'Missouri', 'Maine', 'Pennsylvania', 'Minnesota',
       'Rhode Island', 'Indiana', 'Wyoming', 'Nebraska', 'South Dakota',
       'Iowa', 'Washington', 'Idaho', 'Wisconsin',
       'North Carolina', 'Utah', 'Illinois', 'Texas', 'Michigan', 'Oregon',
       'Georgia', 'Oklahoma', 'Tennessee', 'Alabama', 'Arkansas',
       'South Carolina', 'West Virginia', 'Nevada', 'Alaska', 'Hawaii',
       'Mississippi', 'Arizona', 'California', 'New Mexico', 'Louisiana',
       'District of Columbia'])

# %%
#preview final math

final_math_df
# Out:
#                       Average NAEP Math Score over 10 Years
# State
# National public                                       240.0
# Massachusetts                                         250.6
# New Hampshire                                         248.8
# Minnesota                                             249.8
# Vermont                                               243.6
# New Jersey                                            246.8
# Kansas                                                242.6
# North Dakota                                          244.6
# Connecticut                                           241.4
# Maine                                                 242.6
# Montana                                               242.2
# Maryland                                              242.2
# North Carolina                                        243.2
# Ohio                                                  243.2
# Pennsylvania                                          243.8
# ...

# %%
#preview final reading
final_reading_df
# Out:
#                       Average NAEP Reading Score over 10 Years
# State
# National public                                          240.0
# Massachusetts                                            251.0
# New Jersey                                               245.0
# New Hampshire                                            249.0
# Connecticut                                              240.0
# Vermont                                                  243.0
# Virginia                                                 247.0
# Maryland                                                 239.0
# North Dakota                                             245.0
# Colorado                                                 242.0
# Florida                                                  243.0
# Kentucky                                                 242.0
# Delaware                                                 239.0
# Montana                                                  241.0
# ...

# %%
#identify the 5 highest average scores
highest_math_df = final_math_df.sort_values(['Average NAEP Math Score over 10 Years'], ascending=False)
top_10_math_df = highest_math_df.head(10)
print(top_10_math_df)

highest_reading_df = final_reading_df.sort_values(['Average NAEP Reading Score over 10 Years'], ascending=False)
top_10_reading_df = highest_reading_df.head(10)
print(top_10_reading_df)
# Out:
#                Average NAEP Math Score over 10 Years
# State
# Massachusetts                                  250.6
# Minnesota                                      249.8
# New Hampshire                                  248.8
# New Jersey                                     246.8
# Indiana                                        246.6
# Virginia                                       246.6
# Wyoming                                        246.4
# North Dakota                                   244.6
# Pennsylvania                                   243.8
# Vermont                                        243.6
#                 Average NAEP Reading Score over 10 Years
# State
# Massachusetts                                      251.0
# Minnesota                                          250.0
# New Hampshire                                      249.0
# Indiana                                            248.0
# Wyoming                                            247.0
# ...

# %%
#identify the 5 lowest average scores
lowest_math_df = final_math_df.sort_values(['Average NAEP Math Score over 10 Years'], ascending=True)
bottom_10_math_df = lowest_math_df.head(10)
print(bottom_10_math_df)

lowest_reading_df = final_reading_df.sort_values(['Average NAEP Reading Score over 10 Years'], ascending=True)
bottom_10_reading_df = lowest_reading_df.head(10)
print(bottom_10_reading_df)
# Out:
#                       Average NAEP Math Score over 10 Years
# State
# District of Columbia                                  229.6
# Louisiana                                             231.2
# Alabama                                               231.4
# New Mexico                                            231.6
# California                                            233.4
# Alaska                                                234.0
# Mississippi                                           234.2
# West Virginia                                         234.8
# Nevada                                                235.0
# Arkansas                                              236.0
#                       Average NAEP Reading Score over 10 Years
# State
# District of Columbia                                     231.0
# New Mexico                                               231.0
# Alabama                                                  231.0
# ...

# %%
#Write the file out for visualization 

#bar graph, country vs all for both math and reading
#add hline = to national public value
#save (.savefig)
x_axis = np.arange(len(final_math_df))
tick_locations = [value+0.4 for value in x_axis]
plt.figure(figsize=(20,5))
plt.bar(x_axis, final_math_df["Average NAEP Math Score over 10 Years"], color='r', alpha=0.5, align="edge")
plt.xticks(tick_locations, final_math_df.index, rotation="vertical")
plt.xlim(-0.25, len(x_axis))
plt.ylim(0, max(final_math_df["Average NAEP Math Score over 10 Years"])+10)
plt.title("Average NAEP Math Score Over 10 Years")
plt.xlabel("State")
plt.ylabel("Score")
plt.hlines(final_math_df.iloc[0,0], 0, len(final_math_df), alpha = 0.5)
plt.savefig("national_math_scores.png", bbox_inches='tight')
plt.show()

# %%
#bar graph, country vs all reading
#add hline = to national public value
#save (.savefig)
x_axis = np.arange(len(final_reading_df))
tick_locations = [value+0.4 for value in x_axis]
plt.figure(figsize=(20,5))
plt.bar(x_axis, final_reading_df["Average NAEP Reading Score over 10 Years"], color='r', alpha=0.5, align="edge")
plt.xticks(tick_locations, final_reading_df.index, rotation="vertical")
plt.xlim(-0.25, len(x_axis))
plt.ylim(0, max(final_reading_df["Average NAEP Reading Score over 10 Years"])+10)
plt.title("Average NAEP Reading Score Over 10 Years")
plt.xlabel("State")
plt.ylabel("Score")
plt.hlines(final_reading_df.iloc[0,0], 0, len(final_reading_df), alpha = 0.5)
plt.savefig("Images_education/national_reading_scores.png", bbox_inches='tight')
plt.show()

# %%
#bar graph, top 5 for both reading
x_axis = np.arange(len(top_10_reading_df))
tick_locations = [value+0.4 for value in x_axis]
plt.figure(figsize=(20,5))
plt.bar(x_axis, top_10_reading_df["Average NAEP Reading Score over 10 Years"], color='r', alpha=0.5, align="edge")
plt.xticks(tick_locations, top_10_reading_df.index, rotation="horizontal")
plt.xlim(-0.25, len(x_axis))
plt.ylim(0, max(top_10_reading_df["Average NAEP Reading Score over 10 Years"])+10)
plt.title("Top 10 Reading Scores")
plt.xlabel("State")
plt.ylabel("Score")
plt.savefig("Images_education/top_10_reading.png", bbox_inches='tight')
plt.show()

# %%
# and math
x_axis = np.arange(len(top_10_math_df))
tick_locations = [value+0.4 for value in x_axis]
plt.figure(figsize=(20,5))
plt.bar(x_axis, top_10_math_df["Average NAEP Math Score over 10 Years"], color='r', alpha=0.5, align="edge")
plt.xticks(tick_locations, top_10_math_df.index, rotation="horizontal")
plt.xlim(-0.25, len(x_axis))
plt.ylim(0, max(top_10_math_df["Average NAEP Math Score over 10 Years"])+10)
plt.title("Top 10 Math Scores")
plt.xlabel("State")
plt.ylabel("Score")
plt.savefig("Images_education/top_10_math.png", bbox_inches='tight')
plt.show()

# %%
#bar graph, bottom 5 for both reading
x_axis = np.arange(len(bottom_10_reading_df))
tick_locations = [value+0.4 for value in x_axis]
plt.figure(figsize=(20,5))
plt.bar(x_axis, bottom_10_reading_df["Average NAEP Reading Score over 10 Years"], color='r', alpha=0.5, align="edge")
plt.xticks(tick_locations, bottom_10_reading_df.index, rotation="horizontal")
plt.xlim(-0.25, len(x_axis))
plt.ylim(0, max(bottom_10_reading_df["Average NAEP Reading Score over 10 Years"])+10)
plt.title("Bottom 10 Reading Scores")
plt.xlabel("State")
plt.ylabel("Score")
plt.savefig("Images_education/bottom_10_reading.png", bbox_inches='tight')
plt.show()

# %%
# and math
x_axis = np.arange(len(bottom_10_math_df))
tick_locations = [value+0.4 for value in x_axis]
plt.figure(figsize=(20,5))
plt.bar(x_axis, bottom_10_math_df["Average NAEP Math Score over 10 Years"], color='r', alpha=0.5, align="edge")
plt.xticks(tick_locations, bottom_10_math_df.index, rotation="horizontal")
plt.xlim(-0.25, len(x_axis))
plt.ylim(0, max(bottom_10_math_df["Average NAEP Math Score over 10 Years"])+10)
plt.title("Bottom 10 Math Scores")
plt.xlabel("State")
plt.ylabel("Score")
plt.savefig("Images_education/bottom_10_math.png", bbox_inches='tight')
plt.show()

# %% [markdown]
# Analysis:
